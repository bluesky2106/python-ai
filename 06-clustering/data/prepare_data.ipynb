# %% [markdown]
# ## Packages & helper functions

# %%
import numpy as np
import pandas as pd
from pymongo import MongoClient

# %%
def connect_mongo(host, port, username, password, db):
    """ A util for making a connection to mongo """

    if username and password:
        mongo_uri = 'mongodb://%s:%d@%s:%s/%s' % (username, password, host, port, db)
        conn = MongoClient(mongo_uri)
    else:
        conn = MongoClient(host, port)


    return conn[db]

# %%
def read_mongo(db, collection, query={}, host='localhost', port=27017, username=None, password=None, no_id=True):
    """ Read from Mongo and Store into DataFrame """

    # Connect to MongoDB
    db = connect_mongo(host=host, port=port, username=username, password=password, db=db)

    # Make a query to the specific DB and Collection
    cursor = db[collection].find(query)

    # Expand the cursor and construct the DataFrame
    df =  pd.DataFrame(list(cursor))

    # Delete the _id
    if no_id:
        del df['_id']

    return df

# %% [markdown]
# ## Prepare data

# %%
raw_data = read_mongo('baochi', 'tuoitre')
raw_data.head(10)
# Out:
#                                              content   category
# 0  Võ sĩ MMA bị knock-out lạ kỳ vì... 'đụng đầu' ...   Thể thao
# 1  Thi đấu từ máy bay ở độ cao 6.096m, ngôi sao 6...   Thể thao
# 2  Ấn Độ yêu cầu mạng xã hội gỡ cụm từ 'biến thể ...  Công nghệ
# 3  Tay đua 19 tuổi Jason Dupasquier qua đời sau t...   Thể thao
# 4  Cảnh sát Ấn Độ 'cảnh báo' Công ty Twitter TTO ...  Công nghệ
# 5  Sủng Cỏ thiên đường hoang sơ nơi cửa vịnh Đà N...    Du lịch
# 6  Giận liên đoàn, CĐV Indonesia không vào sân cổ...   Thể thao
# 7  Google bỏ cookie theo dõi người dùng là để 'là...  Công nghệ
# 8  Võ sĩ hạng nặng đánh nhau trên sàn đấu, khán g...   Thể thao
# 9  Bánh trứng thời nghèo khó Dan Bing bỗng len lỏ...    Du lịch

# %%
raw_data.groupby('category').size()
# Out:
# category
# Công nghệ    1579
# Du lịch      2535
# Thể thao     3058
# dtype: int64

# %%
num_of_rows = 50
thethao = raw_data[raw_data.category == 'Thể thao']
thethao = thethao.iloc[:num_of_rows]

congnghe = raw_data[raw_data.category == 'Công nghệ']
congnghe = congnghe.iloc[:num_of_rows]

dulich = raw_data[raw_data.category == 'Du lịch']
dulich = dulich.iloc[:num_of_rows]

# %%
thethao
# Out:
#                                                content  category
# 0    Võ sĩ MMA bị knock-out lạ kỳ vì... 'đụng đầu' ...  Thể thao
# 1    Thi đấu từ máy bay ở độ cao 6.096m, ngôi sao 6...  Thể thao
# 3    Tay đua 19 tuổi Jason Dupasquier qua đời sau t...  Thể thao
# 6    Giận liên đoàn, CĐV Indonesia không vào sân cổ...  Thể thao
# 8    Võ sĩ hạng nặng đánh nhau trên sàn đấu, khán g...  Thể thao
# 11   Duy Mạnh, Đình Trọng, Minh Vương đã bình phục ...  Thể thao
# 12   Vòng đấu cuối Giải ngoại hạng Anh (Premier Lea...  Thể thao
# 16   Đội tuyển Việt Nam tiếp tục xét nghiệm COVID-1...  Thể thao
# 19   Video: Thống kê và phong độ của ba thủ môn đội...  Thể thao
# 21   HLV Nishino 'hài lòng' dù đội tuyển Thái Lan t...  Thể thao
# 23   Thái Lan thảm bại 1-4 trước Uzbekistan TTO - Đ...  Thể thao
# 34   Thủ môn chạy ra góc 'giành bóng' với đồng đội ...  Thể thao
# 46   Duy Mạnh không kịp phục hồi 100% cho AFF Cup 2...  Thể thao
# 49   Liverpool vào top 4, tranh vé dự Champions Lea...  Thể thao
# 51   Alisson ghi bàn phút 90+5, Liverpool sống lại ...  Thể thao
# 53   Tận dụng công nghệ để chống dịch TTO - Với thế...  Thể thao
# 54   Những hình ảnh ấn tượng trong trận thắng UAE T...  Thể thao
# 169  FPT Telecom nhận giải thưởng 'Chất lượng dịch ...  Công nghệ
# 183  Thượng viện Úc thông qua luật bắt Facebook, Go...  Công nghệ
# 185  Sau Úc, nhiều nước sắp ra luật yêu cầu Faceboo...  Công nghệ
# 188  Facebook khôi phục tin tức tại Úc, đang thỏa t...  Công nghệ
# 197  Ứng viên trẻ 'né' Facebook sau bê bối dữ liệu ...  Công nghệ
# 201  Thành viên Tổ Thông tin đáp ứng nhanh nhận bằn...  Công nghệ
# 202  Buộc Facebook, Google trả phí cho báo chí: Việ...  Công nghệ
# 216  Úc 'đấu trí' với Facebook và Google, các báo n...  Công nghệ
# 221  Facebook cam kết đầu tư 1 tỉ USD cho báo chí T...  Công nghệ
# 224  Facebook, Instagram chặn vô thời hạn các tài k...  Công nghệ
# 228  Nộp thay thuế cho Google, Facebook, Amazon: Ng...  Công nghệ

# %%
dulich
# Out:
#                                                content category
# 5    Sủng Cỏ thiên đường hoang sơ nơi cửa vịnh Đà N...  Du lịch
# 9    Bánh trứng thời nghèo khó Dan Bing bỗng len lỏ...  Du lịch
# 13   Chò nâu khoe sắc, xoay tít như chong chóng giữ...  Du lịch
# 14   Du lịch miền Trung phải bắt tay nhau để cùng t...  Du lịch
# 17   Tiền đạo Văn Toàn: 'Chiến thắng sẽ giúp mọi ng...  Du lịch
# 18   5 tỉnh miền Trung bắt tay Hà Nội, TP.HCM kéo k...  Du lịch
# 20   Du lịch phải 'nắm tay nhau cùng đi' TTO - Chiề...  Du lịch
# 25   InterContinental Phu Quoc bắt nhịp xu hướng du...  Du lịch
# 26   Tour Phú Quốc 3 ngày 2 đêm từ TP.HCM ưu đãi ch...  Du lịch
# 28   Có gì ở giai đoạn 2 dự án Yoko Onsen Quang Han...  Du lịch
# 31   Sun World và Klook công bố quan hệ đối tác chi...  Du lịch
# 32   Facebook trả tiền cho 14 cơ quan báo chí Canad...  Du lịch
# 33   ‘Nghỉ thảnh thơi - chơi thỏa thích’ với chùm t...  Du lịch
# 36   Trải nghiệm ẩm thực Thái Lan tại Khách sạn Win...  Du lịch
# 38   Vắc xin chưa ổn lại lo thêm ‘hộ chiếu vắc xin’...  Du lịch
# 39   Châu Âu đạt thỏa thuận về ‘hộ chiếu vắc xin’ T...  Du lịch
# 42   Tiếp tục bị khóa tài khoản, ông Trump nói Face...  Du lịch
# 43   Mỹ nhân xứ Huế - Kỳ 5: Giai nhân Huế đưa ẩm th...  Du lịch
# 44   Về rừng ăn lẩu mắm U Minh TTO - "Ác với nhau c...  Du lịch
# 52   Quảng Nam 'trả lương' cho 13 nhà cổ tư nhân tr...  Du lịch
# 55   4 việc cần làm cho du lịch Việt TTO - Sau bài ...  Du lịch
# 58   Café Central The Garden Mall chính thức ra mắt...  Du lịch
# 59   Tour Thụy Sĩ, Pháp, Đức, Hà Lan, Bỉ từ 24.090....  Du lịch
# 61   Onsen Quang Hanh - khi những giá trị vàng được...  Du lịch
# 63   Chủ tịch UBND quận Gò Vấp: Hôm nay người dân t...  Du lịch
# 65   Đầu năm ăn hàu cho sung để cả năm được sướng T...  Du lịch
# 67   Hoa chò nâu Sài Gòn xoay tít đón hè TTO - Thán...  Du lịch
# 72   Có thể bị phạt tù khi mang thực phẩm, rau củ đ...  Du lịch
# 78   Tour Thụy Sĩ, Pháp, Đức, Hà Lan, Bỉ từ 24.090....  Du lịch
# 80   Lý giải sức bật mạnh mẽ của du lịch Tây Ninh V...  Du lịch
# 82   Công ty du lịch Việt Nam bán tour đi Mỹ tiêm v...  Du lịch
# 84   Bóng đá VN quyết tâm diệt trừ nạn tiêu cực TTO...  Du lịch
# 86   Việt Nam đang nghiên cứu cơ chế ‘hộ chiếu vắc ...  Du lịch
# 88   Du khách ghé Đà Nẵng, Quảng Nam và Thừa Thiên ...  Du lịch
# 90   Belarus đóng cửa đại sứ quán ở Canada sau vụ v...  Du lịch
# 94   Quảng Ninh đặt mục tiêu đón 3 triệu lượt khách...  Du lịch
# 96   Quảng Ninh tung tiếp gói hỗ trợ 500 tỉ 'cứu' d...  Du lịch
# 98   Các nước đòi làm rõ vụ Đan Mạch giúp Mỹ nghe l...  Du lịch
# 101  Chặn đứng nhiều tốp người vượt biên trên tuyến...  Du lịch
# 102  Saigontourist Group: Liên kết vùng mang đến  n...  Du lịch
# 103  Saigontourist Group tung chương trình ưu đãi "...  Du lịch
# 104  12 huyện đảo chờ khám phá TTO - Một cuộc gặp m...  Du lịch
# 105  Tour Thụy Sĩ, Ý, Slovenia, Croatia - công viên...  Du lịch
# 109  Anh phân loại địa điểm du lịch theo màu đèn gi...  Du lịch
# 111  Nhu cầu 'bùng nổ', công ty du lịch mở thêm tuy...  Du lịch
# 113  Du khách vội vàng hủy tour, các công ty du lịc...  Du lịch
# 117  Đại sứ Ukraine ở Thái Lan bất ngờ qua đời TTO ...  Du lịch
# 118  Khách đến Đà Nẵng dịp lễ 30-4 và 1-5 chỉ đạt 5...  Du lịch
# 123  Liên kết vùng để kích cầu du lịch TTO - Chiều ...  Du lịch
# 126  Phát hiện hành khách tàng trữ đạn quân dụng ở ...  Du lịch

# %%
data = thethao
data = data.append(congnghe)
data = data.append(dulich)
data
# Out:
#                                                content  category
# 0    Võ sĩ MMA bị knock-out lạ kỳ vì... 'đụng đầu' ...  Thể thao
# 1    Thi đấu từ máy bay ở độ cao 6.096m, ngôi sao 6...  Thể thao
# 3    Tay đua 19 tuổi Jason Dupasquier qua đời sau t...  Thể thao
# 6    Giận liên đoàn, CĐV Indonesia không vào sân cổ...  Thể thao
# 8    Võ sĩ hạng nặng đánh nhau trên sàn đấu, khán g...  Thể thao
# ..                                                 ...       ...
# 113  Du khách vội vàng hủy tour, các công ty du lịc...   Du lịch
# 117  Đại sứ Ukraine ở Thái Lan bất ngờ qua đời TTO ...   Du lịch
# 118  Khách đến Đà Nẵng dịp lễ 30-4 và 1-5 chỉ đạt 5...   Du lịch
# 123  Liên kết vùng để kích cầu du lịch TTO - Chiều ...   Du lịch
# 126  Phát hiện hành khách tàng trữ đạn quân dụng ở ...   Du lịch
#
# [150 rows x 2 columns]

# %%
data.to_csv('raw_data.csv', sep=',', index=False)
