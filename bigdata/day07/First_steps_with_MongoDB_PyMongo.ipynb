# %% [markdown]
# # Quick intro to MongoDB and PyMongo
#
#
# *   Connection to Mongo
# *   Basic database, collection management
# *   CRUD (Create Operations; Read Operations; Update Operations; Delete Operations)  one document
# *   CRUD (Create Operations; Read Operations; Update Operations; Delete Operations) many documents

# %% [markdown]
# # 1. Install PyMongo (if required)

# %%
# Instaling PyMongo, this is the interface to connect to MongoDB with Python
! python -m pip install pymongo==3.7.2
# Out:
# /System/Library/Frameworks/Python.framework/Versions/2.7/Resources/Python.app/Contents/MacOS/Python: No module named pip

# %% [markdown]
# #2. Import PyMongo and establish connection
#
# To practice MongoDB, you can use a free service with limited storage to train or test the code.
#
# Here for the example, we can use https://www.clever-cloud.com/en/
#
# Other services:
#
# https://studio3t.com/knowledge-base/articles/cheap-free-mongodb-hosting/

# %%
import datetime                            # Imports datetime library

import pymongo
from pymongo import MongoClient

# uri (uniform resource identifier) defines the connection parameters 
uri = 'mongodb://u1kkdrchfjim80tclysv:FeesC2ACNmI7be61RTst@brny4kjelauboxl-mongodb.services.clever-cloud.com:27017/brny4kjelauboxl'
# start client to connect to MongoDB server 
client = MongoClient( uri )

# %%
client.stats                                # .stats  show details about the client
# Out:
# Database(MongoClient(host=['brny4kjelauboxl-mongodb.services.clever-cloud.com:27017'], document_class=dict, tz_aware=False, connect=True), 'stats')

# %% [markdown]
# # 3. Basic Database management operations

# %%
# Show existing database names
client.list_database_names()
# Out:
# ['brny4kjelauboxl']

# %%
# Set database name to work with. If it doesn't exist, it will be created as soon as one document is added.
db = client.brny4kjelauboxl

# %%
# Delete a database
client.drop_database('brny4kjelauboxl')

# %% [markdown]
# #4. Basic Collection management operations

# %%
# Create a new collection. We can create the collection or leave to MongoDB to create it as soon as a document is generated.
db.create_collection('addressbook')       # Optional collection creation
# Out:
# Collection(Database(MongoClient(host=['brny4kjelauboxl-mongodb.services.clever-cloud.com:27017'], document_class=dict, tz_aware=False, connect=True), 'brny4kjelauboxl'), 'addressbook')

# %%
# Show Collections. Query returns a Cursor [ ] ,  list it to see the content
list (db.list_collections())
# empty list '[]' means that there are not collections in database
# Out:
# [{'name': 'addressbook',
#   'type': 'collection',
#   'options': {},
#   'info': {'readOnly': False,
#    'uuid': UUID('398d5834-7ae7-4669-8289-5fbb343b7718')},
#   'idIndex': {'v': 2,
#    'key': {'_id': 1},
#    'name': '_id_',
#    'ns': 'brny4kjelauboxl.addressbook'}}]

# %%
# Set the collection to work with
collection = db.addressbook
collection.insert_one({'name' : 'jordi'})     # Insert one item to create the collection
list(collection.find())                  # Show the existing collections
# Out:
# [{'_id': ObjectId('6121c14a86662df41bc944ff'), 'name': 'jordi'},
#  {'_id': ObjectId('6121c14d86662df41bc94500'), 'name': 'jordi'}]

# %%
# Rename a collections
db.addressbook.rename('addressbook1')
collection = db.adressbook1                 # Set the collection to work with
list (db.list_collections())                  # Show the existing collections
# Out:
# [{'name': 'addressbook1',
#   'type': 'collection',
#   'options': {},
#   'info': {'readOnly': False,
#    'uuid': UUID('398d5834-7ae7-4669-8289-5fbb343b7718')},
#   'idIndex': {'v': 2,
#    'key': {'_id': 1},
#    'name': '_id_',
#    'ns': 'brny4kjelauboxl.addressbook1'}},
#  {'name': 'bicing',
#   'type': 'collection',
#   'options': {},
#   'info': {'readOnly': False,
#    'uuid': UUID('9b925c18-91f3-4d6b-b0de-f3f465723948')},
#   'idIndex': {'v': 2,
#    'key': {'_id': 1},
#    'name': '_id_',
#    'ns': 'brny4kjelauboxl.bicing'}}]

# %%
# Delete collection
db.drop_collection('addressbook1')
# Out:
# {'ns': 'brny4kjelauboxl.addressbook1',
#  'nIndexesWas': 1,
#  'ok': 1.0,
#  'operationTime': Timestamp(1629602144, 68),
#  '$clusterTime': {'clusterTime': Timestamp(1629602144, 68),
#   'signature': {'hash': b'\x83\x93\xf8:\x07[x\xc7\xbb\xf5}L\x8e,\x88c\xf2<V\xb9',
#    'keyId': 6950216782485389313}}}

# %% [markdown]
# # 5. Basic Collection operations

# %% [markdown]
# ##5.1 Query Operators - Create Read Update Delete  (one document)

# %% [markdown]
# ### 5.1.1 Create a document with:  insert_one()

# %% [markdown]
# To insert a document can be done using: insert_one and JavaScript notation  { 'attributeName1'  :  'content1', 'attributeName2'  :  'content2', ... }

# %%
#@title Contact

Name = "An Mai " #@param {type:"string"}
Age = 35 #@param {type:"slider", min:10, max:80, step:1}
Gender = "Male" #@param ["Male", "Female"]
Likes_Python = "Yes" #@param ["Yes", "No"]
if Likes_Python is "Yes":
  Likes_Python = True
else:
  Likes_Python = False


#@markdown Address
Street = "Somewhere on earth" #@param {type:"string"}
Number = 69 #@param {type:"integer"}
City = "Elon Musk" #@param {type:"string"}
PostalCode = "4x0x0x" #@param {type:"string"}
# Out:
# <>:7: SyntaxWarning: "is" with a literal. Did you mean "=="?
# <>:7: SyntaxWarning: "is" with a literal. Did you mean "=="?
# <ipython-input-40-531cb1dc5605>:7: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   if Likes_Python is "Yes":

# %%
data = {  'name' : Name ,                                    # String 
          'age' : Age,                                       # Integer
          'gender' : Gender,                                 # String 
          'likes_python' : Likes_Python,                     # Boolean
          'address': {
              'street' : Street,                             # String ( special character with escape \ )
              'number' : Number,                             # Integer
              'city' : City,                                 # String 
              'floor' : None,                                # Null 
              'postalcode' : PostalCode,                     # String containing a number
              },
          'favouriteFruits': ['banana','pineapple','orange'] # Array        
       }

insert_result = collection.insert_one( data)

# %%
insert_result.acknowledged    # Confirms that insert is successful
# Out:
# True

# %%
insert_result.inserted_id     # Shows the document ID
# Out:
# ObjectId('6121c16886662df41bc94501')

# %% [markdown]
# ###5.1.2 Read document with:  `find()`

# %% [markdown]
# To read a document can be done using: find and JavaScript notation  {  'attribute1 containing the key'  :  'key1 to find' }

# %%
list ( collection.find() )                                      # gets all data of collection
# Out:
# [{'_id': ObjectId('6121c16886662df41bc94501'),
#   'name': 'An Mai ',
#   'age': 35,
#   'gender': 'Male',
#   'likes_python': True,
#   'address': {'street': 'Somewhere on earth',
#    'number': 69,
#    'city': 'Elon Musk',
#    'floor': None,
#    'postalcode': '4x0x0x'},
#   'favouriteFruits': ['banana', 'pineapple', 'orange']}]

# %%
list ( collection.find( {'_id' : insert_result.inserted_id } ))  # Find the inserted document using the objectID
# Out:
# [{'_id': ObjectId('6121c16886662df41bc94501'),
#   'name': 'An Mai ',
#   'age': 35,
#   'gender': 'Male',
#   'likes_python': True,
#   'address': {'street': 'Somewhere on earth',
#    'number': 69,
#    'city': 'Elon Musk',
#    'floor': None,
#    'postalcode': '4x0x0x'},
#   'favouriteFruits': ['banana', 'pineapple', 'orange']}]

# %%
list ( collection.find( {'name' : Name } ))                     # find, can use one key or more
# Out:
# [{'_id': ObjectId('6121c16886662df41bc94501'),
#   'name': 'An Mai ',
#   'age': 35,
#   'gender': 'Male',
#   'likes_python': True,
#   'address': {'street': 'Somewhere on earth',
#    'number': 69,
#    'city': 'Elon Musk',
#    'floor': None,
#    'postalcode': '4x0x0x'},
#   'favouriteFruits': ['banana', 'pineapple', 'orange']}]

# %%
list ( collection.find( {'address.city' : City } ))             # find, can use one key or more
# Out:
# [{'_id': ObjectId('6121c16886662df41bc94501'),
#   'name': 'An Mai ',
#   'age': 35,
#   'gender': 'Male',
#   'likes_python': True,
#   'address': {'street': 'Somewhere on earth',
#    'number': 69,
#    'city': 'Elon Musk',
#    'floor': None,
#    'postalcode': '4x0x0x'},
#   'favouriteFruits': ['banana', 'pineapple', 'orange']}]

# %%
list ( collection.find().limit(1) )                             # gets a Limited set of documents
# Out:
# [{'_id': ObjectId('6121c16886662df41bc94501'),
#   'name': 'An Mai ',
#   'age': 35,
#   'gender': 'Male',
#   'likes_python': True,
#   'address': {'street': 'Somewhere on earth',
#    'number': 69,
#    'city': 'Elon Musk',
#    'floor': None,
#    'postalcode': '4x0x0x'},
#   'favouriteFruits': ['banana', 'pineapple', 'orange']}]

# %%
list ( collection.find().skip(1) )                              # gets all documents skipping first
# Out:
# []

# %% [markdown]
# ###5.1.3 Update a document with:  update_one()

# %%
## Update an existing document
update_result = collection.update_one( 
    {'name' : Name}, 
    {'$set' : { 'age' : 30 }} ) 

list (collection.find( {'name' : Name } ))

# Alternative : collection.find_one_and_update( {'name' : Name}, {'$set' : { 'age' : 30 }} )
# Out:
# [{'_id': ObjectId('6121c16886662df41bc94501'),
#   'name': 'An Mai ',
#   'age': 30,
#   'gender': 'Male',
#   'likes_python': True,
#   'address': {'street': 'Somewhere on earth',
#    'number': 69,
#    'city': 'Elon Musk',
#    'floor': None,
#    'postalcode': '4x0x0x'},
#   'favouriteFruits': ['banana', 'pineapple', 'orange']}]

# %%
update_result.raw_result
# Out:
# {'n': 1,
#  'nModified': 1,
#  'opTime': {'ts': Timestamp(1629602197, 71), 't': 174},
#  'electionId': ObjectId('7fffffff00000000000000ae'),
#  'ok': 1.0,
#  'operationTime': Timestamp(1629602197, 71),
#  '$clusterTime': {'clusterTime': Timestamp(1629602197, 71),
#   'signature': {'hash': b"\x9c\xe3\xa4\xd6,\xa1\x1d\x8d\xae\x87\xb9\xd50\xd1\xde'\xbb\x15@%",
#    'keyId': 6950216782485389313}},
#  'updatedExisting': True}

# %%
## Insert a new document with update, will avoid to crash during insert if document already exist
insert_result = collection.update_one( {'name' : 'Tim Cook'}, {'$set' : { 'age' : 60 }}, upsert= True )
list (collection.find( {'name' : 'Tim Cook'} ))
# Out:
# [{'_id': ObjectId('6121c1ab1aac54792ed67bce'), 'name': 'Tim Cook', 'age': 60}]

# %%
update_result.acknowledged
# Out:
# True

# %% [markdown]
# ###5.1.4 Delete a document with:  `delete_one()`

# %%
delete = collection.delete_one({'name': 'Tim Cook'})

# %%
delete.deleted_count   # informs that 1 document has been deleted
# Out:
# 1

# %%
collection.delete_one({'name': Name})

# %% [markdown]
# ##5.2 Create Read Update Delete  (many document)

# %% [markdown]
# ###5.2.1 Create a document with:  `insert_many()`

# %% [markdown]
# To insert many documents can be done using: `insert_many` and JavaScript notation  `{ 'attributeDocument1'  :  'content1' } , { 'attributeDocument2'  :  'content2'},{ ... }`

# %%
import datetime
collection.insert_many(  [                          # <---- start a list with [
##  Insert Document 1
  {
  'name': 'Marilyn Monroe',
  'age': 95,
  'likes_python': False,
  'registered': datetime.datetime(2021, 8, 3, 4, 22, 39),
  'address': {
      'street': 'Some where on Mars',
      'number': 70,
      'floor': None,
      'city': 'New York',
      'postalCode': '45xx12'
             },
  'height':  1.60,
  'favouriteFruits': ['man','money','love']
  },

##  Insert Document 2
  {
  'name': 'Adogawa Conan',
  'age': 7,
  'likes_python': True,
  'registered': datetime.datetime(2021, 7, 25, 7, 34, 12),
  'address': {
      'street': 'Ran Mori',
                                                     ##  missing number
                                                     ##  missing floor
      'city': 'Tokyo',
      'postalCode': '09099'
             },
  'height':  1.45,
  'favouriteFruits': ['film','youth']
  }
  ]   )                                                   # <---- finalize the list ]

# %% [markdown]
# ###5.2.2 Read many documents with:  find()

# %% [markdown]
# To read a document can be done using: find and JavaScript notation  {  'attribute1 containing the key'  :  'key1 to find' }

# %%
list ( collection.find( {'$or': [ {'name': 'Marilyn Monroe'},{'name': 'Adogawa Conan'} ]}))        # find
# Out:
# [{'_id': ObjectId('61091551f47f70003d7fef4c'),
#   'address': {'city': 'New York',
#    'floor': None,
#    'number': 70,
#    'postalCode': '45xx12',
#    'street': 'Some where on Mars'},
#   'age': 95,
#   'favouriteFruits': ['man', 'money', 'love'],
#   'height': 1.72,
#   'likes_python': False,
#   'name': 'Marilyn Monroe',
#   'registered': datetime.datetime(2021, 8, 3, 4, 22, 39)},
#  {'_id': ObjectId('61091551f47f70003d7fef4d'),
#   'address': {'city': 'Tokyo', 'postalCode': '09099', 'street': 'Maki Azusa'},
#   'age': 70,
#   'favouriteFruits': ['film', 'youth'],
#   'height': 1.56,
#   'likes_python': True,
#   'name': 'Shigeo Tokuda',
#   'registered': datetime.datetime(2021, 7, 25, 7, 34, 12)}]

# %% [markdown]
# ###5.2.3 Update many documents with:  update_many()

# %%
collection.update_many( {'isActive': True }, {'$set' : { 'isActive': False }} )
list (collection.find( ))                                  # List all documents
# Out:
# [{'_id': ObjectId('61091551f47f70003d7fef4c'),
#   'address': {'city': 'New York',
#    'floor': None,
#    'number': 70,
#    'postalCode': '45xx12',
#    'street': 'Some where on Mars'},
#   'age': 95,
#   'favouriteFruits': ['man', 'money', 'love'],
#   'height': 1.72,
#   'likes_python': False,
#   'name': 'Marilyn Monroe',
#   'registered': datetime.datetime(2021, 8, 3, 4, 22, 39)},
#  {'_id': ObjectId('61091551f47f70003d7fef4d'),
#   'address': {'city': 'Tokyo', 'postalCode': '09099', 'street': 'Maki Azusa'},
#   'age': 70,
#   'favouriteFruits': ['film', 'youth'],
#   'height': 1.56,
#   'likes_python': True,
#   'name': 'Shigeo Tokuda',
#   'registered': datetime.datetime(2021, 7, 25, 7, 34, 12)}]

# %% [markdown]
# ###5.2.4 Delete many documents with:  `delete_many()`

# %%
delete = collection.delete_many({'likes_python': True})    # deletes as many documents as the filter
list (collection.find( ))                                  # List all documents
# Out:
# [{'_id': ObjectId('61091551f47f70003d7fef4c'),
#   'address': {'city': 'New York',
#    'floor': None,
#    'number': 70,
#    'postalCode': '45xx12',
#    'street': 'Some where on Mars'},
#   'age': 95,
#   'favouriteFruits': ['man', 'money', 'love'],
#   'height': 1.72,
#   'likes_python': False,
#   'name': 'Marilyn Monroe',
#   'registered': datetime.datetime(2021, 8, 3, 4, 22, 39)}]

# %%
delete.deleted_count   # items deleted
# Out:
# 1

# %% [markdown]
# ## An example

# %% [markdown]
# ### Set up MongoDB

# %%
# MongoDB download and installation
# !wget https://fastdl.mongodb.org/linux/mongodb-linux-x86_64-debian71-3.0.15.tgz  # Downloads MongoDB from official repository
# !tar xfv mongodb-linux-x86_64-debian71-3.0.15.tgz  >/dev/null                    # Unpack compressed file
# !rm mongodb-linux-x86_64-debian71-3.0.15.tgz                                     # Removes downloaded file

# dataset = "https://www.bicing.cat/availability_map/getJsonObject"     # Get JSON file from bicing
dataset = "https://raw.githubusercontent.com/Giffy/MongoDB_PyMongo_Tutorial/master/resources/bicing_data.csv"  
# !wget $dataset                                                                   # gets_dataset

# Uploading data to Mongo Database
# !mongodb-linux-x86_64-debian71-3.0.15/bin/mongoimport --host brny4kjelauboxl-mongodb.services.clever-cloud.com \
                                                      --port 27017 \
                                                      --username='u1kkdrchfjim80tclysv' \
                                                      --password='FeesC2ACNmI7be61RTst' \
                                                      --db brny4kjelauboxl \
                                                      --collection bicing \
                                                      --type csv\
                                                      --file bicing_data.csv\
                                                      --drop --headerline
# Out:
# --2021-08-22 10:18:39--  https://fastdl.mongodb.org/linux/mongodb-linux-x86_64-debian71-3.0.15.tgz
# Resolving fastdl.mongodb.org (fastdl.mongodb.org)... 13.225.4.125, 13.225.4.86, 13.225.4.77, ...
# Connecting to fastdl.mongodb.org (fastdl.mongodb.org)|13.225.4.125|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 70878938 (68M) [application/x-gzip]
# Saving to: ‘mongodb-linux-x86_64-debian71-3.0.15.tgz’
#
# mongodb-linux-x86_6 100%[===================>]  67.59M  5.97MB/s    in 14s
#
# 2021-08-22 10:18:55 (4.70 MB/s) - ‘mongodb-linux-x86_64-debian71-3.0.15.tgz’ saved [70878938/70878938]
#
# x mongodb-linux-x86_64-debian71-3.0.15/README
# x mongodb-linux-x86_64-debian71-3.0.15/THIRD-PARTY-NOTICES
# x mongodb-linux-x86_64-debian71-3.0.15/GNU-AGPL-3.0
# x mongodb-linux-x86_64-debian71-3.0.15/bin/mongodump
# x mongodb-linux-x86_64-debian71-3.0.15/bin/mongorestore
# x mongodb-linux-x86_64-debian71-3.0.15/bin/mongoexport
# ...

# %%
# !pip install pymongo==3.7.2 folium==0.8.3  >/dev/null
# Out:
# DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
#   DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
#   DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
# ...

# %%
import pymongo                            # Library to access MongoDB
from pymongo import MongoClient           # Imports MongoClient 
import pandas as pd                       # Library to work with dataframes
import folium                             # Library to visualize a map

# %% [markdown]
# ### Connect the the database

# %%
# uri (uniform resource identifier) defines the connection parameters 
# uri = 'mongodb:// USER : PASSWORD @ SERVER_NAME : PORT / DATABASENAME')
# uri = 'mongodb:// USER : PASSWORD @ SERVER_NAME : PORT / DATABASE_NAME, CLUSTER_1_NAME : PORT , CLUSTER_2_NAME : PORT')
# uri = 'localhost:27017'
uri = 'mongodb://u1kkdrchfjim80tclysv:FeesC2ACNmI7be61RTst@brny4kjelauboxl-mongodb.services.clever-cloud.com:27017/brny4kjelauboxl'

# start client to connect to MongoDB server 
client = MongoClient( uri )

# %%
db = client.brny4kjelauboxl               # Set the database to work on
db.list_collection_names()                # List the collections available
collection = db.bicing

# %% [markdown]
# ### Quick data overview

# %%
num_documents = collection.count_documents({'_id' : {'$exists' : 1}})     # Counts the documents in database
print ( 'Number of documents in database = ' + str(num_documents) )
list ( collection.find().limit(1) )                                       # Shows the first document
# Out:
# Number of documents in database = 926
# [{'_id': ObjectId('6121c1ca1aac54792ed6e583'),
#   'id': 1,
#   'type': 'BIKE',
#   'latitude': 41.397952,
#   'longitude': 2.180042,
#   'streetName': 'Gran Via Corts Catalanes',
#   'streetNumber': 760,
#   'altitude': 21,
#   'slots': 2,
#   'bikes': 25,
#   'nearbyStations': '24, 369, 387, 426',
#   'status': 'OPN',
#   'updateTime': '01/08/18 17:43:08'}]

# %%
# The values of 'bikes' is string type instead of number. 
# In order to filter by number greater than, we need to convert the value to integer.
# to change an attribute type, can be done easily with mongoDB 4 
# In workshop we use mongo 3, I suggest to use the following method to convert it

bikes_list = list(collection.distinct('bikes'))             # list the unique values of 'bikes', we get a list of strings 
for num in bikes_list:                                      # iterate the list, item by item
  collection.update_many({'bikes' : num},{'$set': {'bikes' : int(num)}})    # update each document with a number in string with the same number as Integer

# %% [markdown]
# ### Query to database: Get active stations with at least 3 bicycles

# %%
# Loading database query in pandas Dataframe
filters = {'status':'OPN', 'bikes' : {'$gte' : 3 }}   # Usage of gte Query Operator  $gte = "greater than or equal"
fields = { '_id', 'latitude' , 'longitude', 'bikes', 'slots'}

query = list( collection.find( filters , fields ) )
df = pd.DataFrame ( query )

# %%
print ( 'Numer of active stations with at least 3 bicycles: ' + str(len (query)) )
# Out:
# Numer of active stations with at least 3 bicycles: 662

# %%
df.iloc[0] # prints the first DataFrame row
# Out:
# _id          6121c1ca1aac54792ed6e583
# latitude                    41.397952
# longitude                    2.180042
# slots                               2
# bikes                              25
# Name: 0, dtype: object

# %%
df.head()
# Out:
#                         _id   latitude  longitude  slots  bikes
# 0  6121c1ca1aac54792ed6e583  41.397952   2.180042      2     25
# 1  6121c1ca1aac54792ed6e584  41.395530   2.177060      0     27
# 2  6121c1ca1aac54792ed6e585  41.393470   2.181490     11      7
# 3  6121c1ca1aac54792ed6e586  41.394072   2.183441     19      7
# 4  6121c1ca1aac54792ed6e587  41.391349   2.180610     18     17

# %% [markdown]
# ### Mark Bicing stations in map

# %%
center_lat = 41.378
center_lon = 2.139

locationmap = folium.Map(location=[ center_lat , center_lon ], zoom_start=16, width=800, height=600 )
longitud  = len( df )

for i in range ( longitud ):
    lng = float(df.iloc[i]['longitude'])
    lat = float(df.iloc[i]['latitude'])
    description = 'Bikes: ' + str(df.iloc[i]['bikes']) + '<br> Empty slots: ' + str(df.iloc[i]['slots'])
    folium.Marker( [ lat , lng ],
                 popup= description,
                 icon=folium.Icon(color='red')).add_to(locationmap)

locationmap
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%3Cscript%3EL_PREFER_CANVAS%3Dfalse%3B%20L_NO_TOUCH%3Dfalse%3B%20L_DISABLE_3D%3Dfalse%3B%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.4.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.co
# ...
